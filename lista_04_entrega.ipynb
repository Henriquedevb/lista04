# %% [markdown]
# <a href="https://colab.research.google.com/github/Henriquedevb/lista04/blob/main/lista_04_entrega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
QUESTÃO 01: 

 Escreva um programa para ler o número de lados de um polígono regular e a medida do lado (em cm). Calcular e imprimir o seguinte: 
Se o número de lados for igual a 3 escrever TRIÂNGULO e o valor da área.
Se o número de lados for igual a 4 escrever QUADRADO e o valor da sua área. 
Se o número de lados for igual a 5 escrever PENTÁGONO. 

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4

import math #importa biblioteca que faz a raiz quadrada na area do triangulo.

#Apresentação do que o programa faz e como deve ser utilizado com base no enunciado da questão.
presentation = ('\n\nOlá seja bem vindo \n\n A qualquer momento para sair tecle 0 \n\nEscreva no programa abaixo a quantidade de lados de um poligono regular entre 3 e 5 e sua medida conforme solicitado.')


print(presentation) #inicia o programa
print('-------------------------------------------\n-------------------------------------------')

while True:
    numeroLados = int(input('\nDiga quantos lados tem seu poligono regular: ')) #recebe o valor inicial do programa



    if numeroLados == 3: # Verifica se o numero recebido é valido com o enunciado
        print('\nTRIÂNGULO') #imprime o que pede na questão
        print('-------------------------------------------\n-------------------------------------------') #espaço para melhorar a visualização
        tamanho = float(input('Informe a medida de seu triângulo em centimetros(CM): ')) #recebe o tamanho em centimetros
        if tamanho == 0: #verifica se foi solicitado a parada do programa
            print('Você saiu :) ') #Avisa que o saiu do programa
            break #faz o programa encerrar
        altura = tamanho * (math.sqrt(3) / 2) #faz o calcuro da area do triangulo com a utilizção da biblioteca math
        print('Area = ', ((altura * tamanho) / 2)) #Escreve a area calculada
        
    
    elif numeroLados == 4: # Verifica se o numero recebido é valido com o enunciado
        print('\nQUADRADO') #imprime o que pede na questão
        tamanho = float(input('Informe a medida de seu quadrado em centimetros(CM): ')) #recebe o tamanho em centimetros
        if tamanho == -0: #verifica se foi solicitado a parada do programa
            print('Você saiu :) ') #Avisa que o saiu do programa
            break #faz o programa encerrar
        areaQuadrado = tamanho**tamanho #faz 0 calculo da area do quadrado
        print('Area = ', areaQuadrado) #Escreve a area calculada
    
    elif numeroLados == 5: # Verifica se o numero recebido é valido com o enunciado
        print('\nPENTÁGONO') #imprime o que pede na questão

    elif numeroLados == 0: #verifica se foi solicitado o encerramento do programa
        print('Você saiu :) ') #Avisa que o saiu do programa
        break #faz o programa encerrar
    
    elif numeroLados <3 or numeroLados >5: #verifica se o numero inserido é valido de acordo com o enunciado
        print('\nValor invalido. Tente novamente.') #avisa que o valor é invalido e pede para repetir a ação 
        
QUESTÃO 02 :

Acrescente as seguintes mensagens à solução do exercício anterior conforme o caso.
Caso o número de lados seja inferior a 3 escrever NÃO É UM POLÍGONO.
Caso o número de lados seja superior a 5 escrever POLÍGONO NÃO IDENTIFICADO. 

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4

import math #importa biblioteca que faz a raiz quadrada na area do triangulo.

#Apresentação do que o programa faz e como deve ser utilizado com base no enunciado da questão.
presentation = ('\n\nOlá seja bem vindo \n\n A qualquer momento para sair tecle 0 \n\nEscreva no programa abaixo a quantidade de lados de um poligono regular entre 3 e 5 e sua medida conforme solicitado.')


print(presentation) #inicia o programa
print('-------------------------------------------\n-------------------------------------------')

while True:
    numeroLados = int(input('\nDiga quantos lados tem seu poligono regular: ')) #recebe o valor inicial do programa



    if numeroLados == 3: # Verifica se o numero recebido é valido com o enunciado
        print('\nTRIÂNGULO') #imprime o que pede na questão
        print('-------------------------------------------\n-------------------------------------------') #espaço para melhorar a visualização
        tamanho = float(input('Informe a medida de seu triângulo em centimetros(CM): ')) #recebe o tamanho em centimetros
        if tamanho == 0: #verifica se foi solicitado a parada do programa
            print('Você saiu :) ') #Avisa que o saiu do programa
            break #faz o programa encerrar
        altura = tamanho * (math.sqrt(3) / 2) #faz o calcuro da area do triangulo com a utilizção da biblioteca math
        print('Area = ', ((altura * tamanho) / 2)) #Escreve a area calculada
        
    
    elif numeroLados == 4: # Verifica se o numero recebido é valido com o enunciado
        print('\nQUADRADO') #imprime o que pede na questão
        tamanho = float(input('Informe a medida de seu quadrado em centimetros(CM): ')) #recebe o tamanho em centimetros
        if tamanho == -0: #verifica se foi solicitado a parada do programa
            print('Você saiu :) ') #Avisa que o saiu do programa
            break #faz o programa encerrar
        areaQuadrado = tamanho**tamanho #faz 0 calculo da area do quadrado
        print('Area = ', areaQuadrado) #Escreve a area calculada
    
    elif numeroLados == 5: # Verifica se o numero recebido é valido com o enunciado
        print('\nPENTÁGONO') #imprime o que pede na questão

    elif numeroLados == 0: #verifica se foi solicitado o encerramento do programa
        print('Você saiu :) ') #Avisa que o saiu do programa
        break #faz o programa encerrar
    
    elif numeroLados <3: #verifica se o numero inserido é maior que 3
        print('\nNão é um polígono.') #avisa que não é um poligono
    elif numeroLados >5: #verifica se o numero inserido é maior que 5
        print('\nPolígono não indentificado.') #avisa que não indentificou o poligono
        

QUESTÃO 03:

Escreva um programa para ler 3 valores inteiros e escrever o maior deles.
Considere que o usuário não informará valores iguais. 

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4 

apresation = 'Insira 3 números inteiros e que não sejam repetidos.'
print(apresation)


lista = [] #lista vazia para armazenar os 3 valores recebidos de acordo com o enunciado
while True: #faz o looper até achar conseguir 3 valores diferentes
    
    n = int(input('Digite um numero: ')) #recebe um numero
    if n not in lista: #verifica se o numero já não se encontra na lista
        lista.append(n) #adiciona no array o numero depois de ter sido verificado unico
    else:
        print('Valor repetido') #avisa que o valor já está inserido
    if len(lista) == 3: #verifica se q quantidade de numeros recebidos é igual a 3 que é o que pede no enunciado
        print('\nProgama finalizado ..')
        print('O maior valor é: ', max(lista)) #escreve o valor maior que foi armazenado na lista
        break #encerra o programa depois de ter sido feito o que se pede

QUESTÃO 04: 

Escreva um programa que leia as medidas dos lados de um triângulo e escreva
se ele é Equilátero, Isósceles ou Escaleno. 
Sendo que:
Triângulo Equilátero: possui os 3 lados iguais.
Triângulo Isóscele: possui 2 lados iguais.
Triângulo Escaleno: possui 3 lados diferentes. 

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4


a = float(input('Escreva a medida 1 do lado do triângulo: ')) #recebe a primeira medida do triangulo
b = float(input('Escreva a medida 2 do lado do triângulo: ')) #recebe a segunda medida do triangulo
c = float(input('Escreva a medida 3 do lado do triângulo: ')) #recebe a terceira medida do triangulo

if a == b and b == c and c == a: #verifica se os 3 lados são iguais
    print('Triângulo equilatero') #escreve o triangulo referente aos 3 lados iguais
elif a == b or b == c or c == a: #verifica se 2 lados sao iguais
    print('Triângulo isócele') #escreve o triangulo referete a 2 lados iguais
else: 
    print('Triângulo Escaleno') #escreve o triangulo referente a 3 lados diferentes


QUESTÃO 05: 

Escreva um programa que leia o valor de 3 ângulos de um triângulo e escreva se
o triângulo é Acutângulo, Retângulo ou Obtusângulo. 
Sendo que: − 
Triângulo Retângulo: possui um ângulo reto. (igual a 90º)  
Triângulo Obtusângulo: possui um ângulo obtuso. (maior que90º)  
Triângulo Acutângulo: possui três ângulos agudos. (menor que 90º) 

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4

print('Escreva 3 valores de angulos e veja qual triangulo se indentifuca ')


angulo1 = int(input('Digite o valor do primeiro Ângulo: '))#recebe o primeiro valor
angulo2 = int(input('Digite o valor do segundo Ângulo: '))#recebe o segundo valor
angulo3 = int(input('Digite o valor do terceiro Ângulo: '))#recebe o terceiro valor

if angulo1 == 90 or angulo2 == 90 or angulo3 == 90: #verifica se on agulos condizem com Triângulo Retângulo
    print('Triângulo Retângulo') #mostra qual triangulo se indentifuca
elif angulo1 > 90 or angulo2 > 90 or angulo3 > 90:#verifica se on agulos condizem com Triângulo Obtusângulo
    print('Triângulo Obtusângulo')#mostra qual triangulo se indentifuca
elif angulo1 < 90 and angulo2 < 90 and angulo3 < 90:#verifica se on agulos condizem com Triângulo Acutângulo
    print('Triângulo Acutângulo')#mostra qual triangulo se indentifuca
        

QUESTÃO 06:

Faça um programa para ler um número inteiro e imprimir todos os números de 0
até o número lido. 

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4

numero = int(input('Digite um número inteiro: ')) #recebe 1 numero inteiro

cont = -1 #inicializa um contador com -1 para que o primeiro numero impresso seja 0
while True: #faz o loope infinito
    cont += 1 #adiciona 1 numero a cada interação do laço no contador
    print(cont) #imprime os numeros armazenados no contador
    
    if cont == numero: #verifica se ja chegou ao numero inserido no começo do programa
        break #encerra o programa
    
QUESTÃO 07:

Solicitar um número entre 1 e 4. Se a pessoas digitar um número diferente,
mostrar a mensagem "entrada inválida" e solicitar o número novamente. Se
digitar correto mostrar o número digitado. 

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4


numero = int(input('Escreva um número entre 1 e 4: ')) #recebe o numero inteiro entre 1 e 4 para iniciar o programa 
while True: #criando um loop
    if numero<1 or numero>4: #verificando se o numero é invalido
        print('Numero inválido.') # avisando que o numero é invalido
        numero = int(input('Escreva um número entre 1 e 4: ')) #recebendo novamente o numero
        
    elif numero>1 or numero<4: # verificando se o numero é valido
        print('Número digitado: ', numero) # escrevendo o numero 
        break #finalizando o programa
    

QUESTÃO 08:

Fazer um programa que receba varios valores inteiros no teclado (um valor a cada iteração)
e determine o maior dos colocados desde o inicio do programa, A condição de termino do programa é quando o usuario
digitar zero (0). 

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4


print('Digite um número inteiro qualquer.') #apresenta um programa
print('Para encerrar o programa digite 0.') #mostra como encerrar o programa
contador = [] #inicia um array vazio para armazenar os valores digitados das iterações
while True: #inicia um loop
    valores = int(input('Digite um número: ')) #recebe 1 valor em cada iteração
    if valores != 0: #verifica se o numero digitado é diferente de 0
        contador.append(valores) #adiciona no array o numero depois de verificado
    elif valores == 0: #verifica se foi chamado o numero de encerrar o programa
        print('O maior número digitado é', max(contador)) #apresenta o maior numero
        break #encerra o programa
        

QUESTÃO 09:

Escreva um programa Python que leia um número inteiro positivo de 4 dígitos,
calcule e mostre a sua decomposição em unidade, dezena, centena e milhar:
Exemplo: 8531; unidade = 1 dezena = 3 centena = 5 5 milhar = 8

Disciplina: Probabilidade e Estatística
Aluno: Henrique fontenele de jesus
matricula: 2014290022
Lista 4

numero = int(input('Digite um numero de 4 digitos: ')) #recebe o numero que inicia o programa
unidade = numero // 1 % 10 #calculo da unidade
dezena = numero // 10 % 10 #calculo da dezena
centena = numero // 100 % 10 #calculo da centena
milhar = numero // 1000 % 10 #calculo da milhar


print(numero) #mostra o numero digitado
print('unidade', unidade) #mostra a unidade
print('dezena', dezena) #mostra a dezena
print('centena', centena) #mostra a centena
print('milhar', milhar) #mostra a milhar
'''
# Out:
# Digite um numero de 4 digitos: 1998
# 1998
# unidade 8
# dezena 9
# centena 9
# milhar 1
